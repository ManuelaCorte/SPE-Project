# %%
import os
import sys

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
from src.structs import Indicator, Country
from src.utils import plot_time_series, PlotOptions, pacf_plot, acf_plot, Matrix, Float
from src.data import serialize_country_data
from src.statistics import correlation, differencing, stationarity, autocorrelation
import matplotlib.pyplot as plt
from statsmodels.api import OLS
from typing import Literal
import numpy as np

# %%
df = pd.read_csv("../data/cleaned/dataset.csv")
country = Country.ITALY

# %%
def plot_country(country: Country, diff: int = 0):
    df = pd.read_csv("../data/cleaned/dataset.csv")
    features, years = serialize_country_data(df, country, pct=True)
    features_diff: list[Matrix[Literal["N"], Float]] = []
    for indicator in Indicator:
        ts_diff = differencing(features[indicator], diff)
        years_diff = years[diff:]
        features_diff.append(ts_diff)

        plot_time_series(
            years_diff,
            ts_diff,
            13,
            PlotOptions(
                "",
                f"{country.name} {indicator.name}",
                "Date",
                "val",
                [f"{indicator.name}", f"{indicator.name} Average"],
                False,
            ),
        )

        pacf_plot(
            years_diff,
            ts_diff,
            len(years_diff) // 2,
            PlotOptions(
                "",
                f"PACF of {indicator.name}",
                "Lag",
                "val",
                [f"PACF of {indicator.name}"],
                False,
            ),
        )

        acf_plot(
            years_diff,
            ts_diff,
            len(years_diff) // 2,
            PlotOptions(
                "",
                f"ACF of {indicator.name}",
                "Lag",
                "val",
                [f"ACF of {indicator.name}"],
                False,
            ),
        )

        adf, kpss = stationarity(ts_diff)
        print("Stationarity test for", indicator.name)
        print(adf)
        print("")
        print(kpss)
        print()

        acf, pacf = autocorrelation(ts_diff)
        print("Autocorrelation for", indicator.name)
        print(acf)
        print("")
        print(pacf)
        print("--------------------")

    corr = correlation(
        features_diff,
        PlotOptions(
            "",
            f"{country.name} Correlation",
            "Indicator",
            "Indicator",
            [indicator.name for indicator in Indicator],
            False,
        ),
    )
    print("Correlation matrices for Pearson, Spearmen and Kendall tau:")
    print(corr)
    plt.show()

# %%
plot_country(country, 1)

# %%
features, _ = serialize_country_data(df, country, pct=True)
gdp = differencing(features[Indicator.GDP], 0)
ir = differencing(features[Indicator.IR], 0)
cpi = differencing(features[Indicator.CPI], 0)
ols = OLS(gdp, np.column_stack((ir, cpi))).fit()

# %%
ols.summary()

# %%
plot_country(Country.JAPAN, 0)

# %%
import pandas as pd

chunksize: int = 10**4
reader = pd.read_csv(
    "../data/raw/IFS_09-26-2023 00-50-38-77_timeSeries.csv",
    chunksize=chunksize,
    dtype=str,
)

indicators: dict[str, set[str]] = {}
countries: dict[str, set[str]] = {}
for chunk in reader:
    for row in chunk.iterrows():
        row = row[1]
        if indicators.get(row["Country Name"]) is None:
            indicators[row["Country Name"]] = set()
        indicators[row["Country Name"]].add(row["Indicator Name"])

        if countries.get(row["Indicator Name"]) is None:
            countries[row["Indicator Name"]] = set()
        countries[row["Indicator Name"]].add(row["Country Name"])

# %%
indicators["France"]
# Out:
# {'Assets (with Fund Record), US Dollars',
#  'Assets, Direct Investment, Debt Instruments, US Dollars',
#  'Assets, Direct Investment, Equity and Investment Fund Shares, US Dollars',
#  'Assets, Direct Investment, US Dollars',
#  'Assets, Financial Derivatives (Other Than Reserves) and Employee Stock Options, US Dollars',
#  'Assets, Other Investment, Other Equity, US Dollars',
#  'Assets, Other Investment, US Dollars',
#  'Assets, Other Investment: Debt Instruments, US Dollars',
#  'Assets, Portfolio Investment, Debt Securities, US Dollars',
#  'Assets, Portfolio Investment, Equity and Investment Fund Shares, US Dollars',
#  'Assets, Portfolio Investment, US Dollars',
#  'Assets, Reserve Assets, Net (with Fund Record), US Dollars',
#  'Capital Account, Total, Debit, US Dollars',
#  'Central Bank Survey, Claims on Central Government (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Claims on Nonresidents (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Claims on Other Depository Corporations (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Claims on Other Financial Corporations (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Claims on Other Sectors (Euro area-Wide-Residency), Euros',
#  'Central Bank Survey, Claims on Private  Sector (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Claims on Public Nonfinancial Corporations (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Claims on State and Local Government (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Currency in Circulation (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Demand deposits of other sectors (Euro area-Wide-Residency), Euros',
#  'Central Bank Survey, Deposits Excluded from Broad Money (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Deposits and Securities Other than Shares excl. from Monetary Base (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Financial Derivatives (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Liabilities to Central Government (Euro area-Wide-Residency), Euros',
#  'Central Bank Survey, Liabilities to Nonresidents (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Liabilities to Other Depository Corporations (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Loans (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Monetary Base (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Net Claims on Central Government (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Net Foreign Assets (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Other Items Net (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Other Liabilities to Other Depository Corporations (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Other deposits of other sectors (Euro area-Wide-Residency), Euros',
#  'Central Bank Survey, Securities Other than Shares (Euro area-Wide-Residency), Euros',
#  'Central Bank Survey, Securities Other than Shares excl. from Broad Money (Euro Area-Wide-Residency), Euros',
#  'Central Bank Survey, Shares and Other Equity (Euro Area-Wide-Residency), Euros',
#  'Changes in Inventories, Nominal, Domestic Currency',
#  'Changes in Inventories, Nominal, Seasonally Adjusted, Domestic Currency',
#  'Changes in Inventories, Nominal, Unadjusted, Domestic Currency',
#  'Changes in Inventories, Real, Domestic Currency',
#  'Changes in Inventories, Real, Seasonally Adjusted, Domestic Currency',
#  'Changes in Inventories, Real, Unadjusted, Domestic Currency',
#  'Current Account, Goods and Services, Goods, Credit, US Dollars',
#  'Current Account, Goods and Services, Goods, Debit, US Dollars',
#  'Current Account, Goods and Services, Goods, Net, US Dollars',
#  'Current Account, Goods and Services, Net, US Dollars',
#  'Current Account, Goods and Services, Services, Credit, US Dollars',
#  'Current Account, Goods and Services, Services, Debit, US Dollars',
#  'Current Account, Primary Income, Credit, US Dollars',
#  'Current Account, Primary Income, Debit, US Dollars',
#  'Current Account, Secondary Income, Debit, US Dollars',
#  'Depository Corporations Survey, Broad Money Liabilities (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Broad Money Liabilities, Seasonally Adjusted (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Claims on Central Government (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Claims on Other Financial Corporations (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Claims on Private  Sector (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Claims on Public Nonfinancial Corporations (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Claims on State and Local Government (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Deposits Excluded from Broad Money (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Financial Derivatives (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Insurance Technical Reserves ((Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Loans (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Net Claims on Central Government (Euro Area-Wide-Residency), Euros',
#  'Depository Corporations Survey, Securities Other than Shares excl. from Broad Money (Euro Area-Wide-Residency), Euros',
#  'Economic Activity, Industrial Production, Construction, Index',
#  'Economic Activity, Industrial Production, Construction, Percentage change, Corresponding period previous year, Percent',
#  'Economic Activity, Industrial Production, Construction, Percentage change, Previous period, Percent',
#  'Economic Activity, Industrial Production, Energy, Electricity Production, Index',
#  'Economic Activity, Industrial Production, Energy, Electricity Production, Percentage change, Corresponding period previous year, Percent',
#  'Economic Activity, Industrial Production, Energy, Electricity Production, Percentage change, Previous period, Percent',
#  'Economic Activity, Industrial Production, Index',
#  'Economic Activity, Industrial Production, Manufacturing, Index',
#  'Economic Activity, Industrial Production, Manufacturing, Percentage change, Corresponding period previous year, Percent',
#  'Economic Activity, Industrial Production, Manufacturing, Percentage change, Previous period, Percent',
#  'Economic Activity, Industrial Production, Mining, Index',
#  'Economic Activity, Industrial Production, Mining, Percentage change, Corresponding period previous year, Percent',
#  'Economic Activity, Industrial Production, Mining, Percentage change, Previous period, Percent',
#  'Economic Activity, Industrial Production, Percentage change, Corresponding period previous year, Percent',
#  'Economic Activity, Industrial Production, Percentage change, Previous period, Percent',
#  'Employment, Persons, Number of',
#  'Employment, Persons, Percentage change, corresponding period previous year, Percent',
#  'Employment, Persons, Percentage change, previous period, Percent',
#  'Exceptional Financing, US Dollars',
#  'Exchange Rates, Domestic Currency per ECU, End of Period, Rate',
#  'Exchange Rates, Domestic Currency per ECU, Period Average, Rate',
#  'Exchange Rates, Domestic Currency per Euro, End of Period, Rate',
#  'Exchange Rates, Domestic Currency per Euro, Period Average, Rate',
#  'Exchange Rates, Domestic Currency per SDR, End of Period',
#  'Exchange Rates, Domestic Currency per SDR, Period Average',
#  'Exchange Rates, Domestic Currency per U.S. Dollar, End of Period, Rate',
#  'Exchange Rates, Domestic Currency per U.S. Dollar, Period Average, Rate',
#  'Exchange Rates, ECUs per Domestic Currency, End of period, Rate',
#  'Exchange Rates, ECUs per Domestic Currency, Period average, Rate',
#  'Exchange Rates, Euro per Domestic Currency, End of Period, Rate',
#  'Exchange Rates, Euro per Domestic Currency, Period Average, Rate',
#  'Exchange Rates, Nominal Effective Exchange Rate based on Unit Labor Costs, Index',
#  'Exchange Rates, Nominal Effective Exchange Rate, Index',
#  'Exchange Rates, Real Effective Exchange Rate based on Consumer Price Index, Index',
#  'Exchange Rates, Real Effective Exchange Rate based on Unit Labor Costs, Index',
#  'Exchange Rates, SDR per Domestic Currency, End of Period',
#  'Exchange Rates, SDR per Domestic Currency, Period Average',
#  'Exchange Rates, US Dollar per Domestic Currency, End of Period',
#  'Exchange Rates, US Dollar per Domestic Currency, Period Average, Rate',
#  'Exports of Goods and Services, Nominal, Domestic Currency',
#  'Exports of Goods and Services, Nominal, Seasonally Adjusted, Domestic Currency',
#  'Exports of Goods and Services, Nominal, Unadjusted, Domestic Currency',
#  'Exports of Goods and Services, Real, Domestic Currency',
#  'Exports of Goods and Services, Real, Seasonally Adjusted, Domestic Currency',
#  'Exports of Goods and Services, Real, Unadjusted, Domestic Currency',
#  'External Balance of Goods and Services, Nominal, Domestic Currency',
#  'External Balance of Goods and Services, Nominal, Seasonally Adjusted, Domestic Currency',
#  'External Balance of Goods and Services, Nominal, Unadjusted, Domestic Currency',
#  'External Trade, Goods, Deflator/Unit Value of Exports, Free on Board (FOB), Index',
#  'External Trade, Goods, Deflator/Unit Value of Exports, Free on Board (FOB), Percentage change, corresponding period previous year, Percent',
#  'External Trade, Goods, Deflator/Unit Value of Exports, Free on Board (FOB), Percentage change, previous period, Percent',
#  'External Trade, Goods, Deflator/Unit Value of Exports, Free on Board (FOB), in US Dollars, Index',
#  'External Trade, Goods, Deflator/Unit Value of Imports, Cost Insurance Freight (CIF), Index',
#  'External Trade, Goods, Deflator/Unit Value of Imports, Cost Insurance Freight (CIF), Percentage change, corresponding period previous year, Percent',
#  'External Trade, Goods, Deflator/Unit Value of Imports, Cost Insurance Freight (CIF), Percentage change, previous period, Percent',
#  'External Trade, Goods, Deflator/Unit Value of Imports, Cost Insurance Freight (CIF), in US Dollars, Index',
#  'External Trade, Goods, Value of Exports, Free on Board (FOB), Domestic Currency',
#  'External Trade, Goods, Value of Exports, Free on Board (FOB), Percentage change, corresponding period previous year, Percent',
#  'External Trade, Goods, Value of Exports, Free on Board (FOB), Percentage change, previous period, Percent',
#  'External Trade, Goods, Value of Exports, Free on Board (FOB), US Dollars',
#  'External Trade, Goods, Value of Imports, Cost Insurance Freight (CIF), Domestic Currency',
#  'External Trade, Goods, Value of Imports, Cost Insurance Freight (CIF), Percentage change, corresponding period previous year, Percent',
#  'External Trade, Goods, Value of Imports, Cost Insurance Freight (CIF), Percentage change, previous period, Percent',
#  'External Trade, Goods, Value of Imports, Cost, Insurance, Freight (CIF), US Dollars',
#  'External Trade, Goods, Volume of Exports, Free on Board (FOB), Index',
#  'External Trade, Goods, Volume of Exports, Free on Board (FOB), Percentage change, corresponding period previous year, Percent',
#  'External Trade, Goods, Volume of Exports, Free on Board (FOB), Percentage change, previous period, Percent',
#  'External Trade, Goods, Volume of Imports, Cost Insurance Freight (CIF), Index',
#  'External Trade, Goods, Volume of Imports, Cost Insurance Freight (CIF), Percentage change, corresponding period previous year, Percent',
#  'External Trade, Goods, Volume of Imports, Cost Insurance Freight (CIF), Percentage change, previous period, Percent',
#  'Final Consumption Expenditure, Nominal, Seasonally Adjusted, Domestic Currency',
#  'Final Consumption Expenditure, Real, Domestic Currency',
#  'Final Consumption Expenditure, Real, Seasonally Adjusted, Domestic Currency',
#  'Final Consumption Expenditure, Real, Unadjusted, Domestic Currency',
#  'Financial Account, Financial Derivatives (Other Than Reserves) and Employee Stock Options, Net Acquisition of Financial Assets, US Dollars',
#  'Financial Account, Financial Derivatives (Other Than Reserves) and Employee Stock Options, Net Incurrence of Liabilities, US Dollars',
#  'Financial Account, Financial Derivatives (Other Than Reserves) and Employee Stock Options, US Dollars',
#  'Financial Account, Net Lending (+) / Net Borrowing (-) (Balance from Financial Account), Direct Investment, Net Acquisition of Financial Assets, Debt Instruments, US Dollars',
#  'Financial Account, Net Lending (+) / Net Borrowing (-) (Balance from Financial Account), Direct Investment, Net Acquisition of Financial Assets, Equity and Investment Fund Shares, US Dollars',
#  'Financial Account, Net Lending (+) / Net Borrowing (-) (Balance from Financial Account), Direct Investment, Net Acquisition of Financial Assets, US Dollars',
#  'Financial Account, Other Investment, Net Acquisition of Financial Assets, US Dollars',
#  'Financial Account, Other Investment, Other Equity, Net Acquisition of Financial Assets, Debt Instruments, US Dollars',
#  'Financial Account, Other Investment, Other Equity, Net Acquisition of Financial Assets, US Dollars',
#  'Financial Account, Portfolio Investment, Net Acquisition of Financial Assets, Debt Securities, US Dollars',
#  'Financial Account, Portfolio Investment, Net Acquisition of Financial Assets, Equity and Investment Fund Shares, US Dollars',
#  'Financial Account, Portfolio Investment, Net Acquisition of Financial Assets, US Dollars',
#  'Financial Market Prices, Equities, Index',
#  'Financial, Interest Rates, Deposit, Percent per annum',
#  'Financial, Interest Rates, Government Securities, Government Bonds, Percent per annum',
#  'Financial, Interest Rates, Government Securities, Treasury Bills, 3-month, Percent per annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, Loans, Households, Consumer Credit and Other, Up to 1 Year, Percent per annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, Loans, Households, House Purchase, Over 5 Years, Percent per annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, Loans, Non-Financial Corporations, Up to 1 Year, Percent per annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, New Business, Deposits, Households, Agreed Maturity, Up to 1 Year, Percent per annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, New Business, Deposits, Non-financial Corporations, Agreed Maturity, Up to 1 Year, Percent per annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, New Business, Loans, Households, Consumption, Floating Rate and up to 1 Year, Percent per annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, New Business, Loans, Households, House Purchase, Over 5 Years, Percent per annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, New Business, Loans, Non-financial Corporations, Other Than Bank Overdrafts, Over EUR 1 Million, Floating Rate and up to 1 Year, Percent per Annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, Outstanding Amounts, Deposits, Households, Agreed Maturity, Up to 2 Years, Percent per annum',
#  'Financial, Interest Rates, Harmonized Euro Area Rates, Outstanding Amounts, Deposits, Non-Financial Corporations, Agreed Maturity, Up to 2 Years, Percent per annum',
#  'Financial, Interest Rates, Lending Rate, Percent per annum',
#  'Financial, Interest Rates, Money Market, Percent per annum',
#  'Fiscal, General Government, Assets and Liabilities, Debt (at Market Value), Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Currency and Deposits, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Currency and Deposits, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Financial Derivatives, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Financial Derivatives, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Insurance Technical Reserves, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Insurance Technical Reserves, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Loans, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Loans, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Monetary Gold and SDRs, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Monetary Gold and SDRs, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Other Accounts Receivable, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Other Accounts Receivable, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Securities Other than Shares, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Securities Other than Shares, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Shares and Other Equity, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Financial Assets, Shares and Other Equity, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Currency and Deposits, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Currency and Deposits, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Financial Derivatives, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Financial Derivatives, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Insurance Technical Reserves, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Insurance Technical Reserves, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Loans, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Loans, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Other Accounts Payable, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Other Accounts Payable, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Securities Other than Shares, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Securities Other than Shares, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Shares and Other Equity, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Liabilities, Shares and Other Equity, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Net Financial Worth, Classification of the stocks of assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Non-financial Assets, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Assets and Liabilities, Non-financial Assets, Consumption of Fixed Capital, Classification of transactions in assets and liabilities, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Expense, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Expense, Compensation of Employees, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Expense, Consumption of Fixed Capital, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Expense, Interest, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Expense, Social Benefits, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Expense, Subsidies, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Expense, Use of Goods and Services, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Gross operating balance, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Memo Item: Expenditure, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Net Acquisition of Financial Assets Other than Cash, Classification of transactions in assets and liabilities, Transactions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Net Lending/borrowing [NLB], 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Net lending/borrowing, Adjustment to Net lending/borrowing, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Net operating balance, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Primary operating balance, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Revenue, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Revenue, Social Contributions, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Revenue, Tax, 2001 Manual, Domestic Currency',
#  'Fiscal, General Government, Revenue, Tax, Income and Profits, 2001 Manual, Domestic Currency',
#  'Fund Accounts, Currency Holdings as % of Quota, Percent per annum',
#  'Fund Accounts, Currency Holdings, SDRs',
#  'Fund Accounts, Currency Holdings, US Dollars',
#  'Fund Accounts, Lending to the Fund, SDRs',
#  'Fund Accounts, Lending to the Fund, US Dollars',
#  'Fund Accounts, Net Cumulative Allocation, Escrow account, SDRs',
#  'Fund Accounts, Net Cumulative Allocation, Escrow account, US Dollars',
#  'Fund Accounts, Outstanding GRA, SDRs',
#  'Fund Accounts, Outstanding GRA, US Dollars',
#  'Fund Accounts, Outstanding Loans, SDRs',
#  'Fund Accounts, Outstanding Loans, US Dollars',
#  'Fund Accounts, Overdue Obligations, SDRs',
#  'Fund Accounts, Overdue Obligations, US Dollars',
#  'Fund Accounts, Quota, SDRs',
#  'Fund Accounts, Quota, US Dollars',
#  'Fund Accounts, SDR Holdings as % of Allocation, Percent per annum',
#  'Fund Accounts, SDR Holdings, Allocations, SDRs',
#  'Fund Accounts, SDR Holdings, Allocations, US Dollars',
#  'Fund Accounts, UFC & Loans as % of Quota, Percent per annum',
#  'Fund Accounts, UFC & Loans, SDRs',
#  'Fund Accounts, UFC & Loans, US Dollars',
#  'Fund Accounts, Use of Fund Credit and Loans, Reserve Tranche Position, SDRs',
#  'Fund Accounts, Use of Fund Credit and Loans, Reserve Tranche Position, US Dollars',
#  'General Government Final Consumption Expenditure, Nominal, Domestic Currency',
#  'General Government Final Consumption Expenditure, Nominal, Seasonally Adjusted, Domestic Currency',
#  'General Government Final Consumption Expenditure, Nominal, Unadjusted, Domestic Currency',
#  'General Government Final Consumption Expenditure, Real, Domestic Currency',
#  'General Government Final Consumption Expenditure, Real, Seasonally Adjusted, Domestic Currency',
#  'General Government Final Consumption Expenditure, Real, Unadjusted, Domestic Currency',
#  'Gross Capital Formation, Nominal, Domestic Currency',
#  'Gross Capital Formation, Nominal, Seasonally Adjusted, Domestic Currency',
#  'Gross Capital Formation, Nominal, Unadjusted, Domestic Currency',
#  'Gross Capital Formation, Real, Domestic Currency',
#  'Gross Capital Formation, Real, Seasonally Adjusted, Domestic Currency',
#  'Gross Capital Formation, Real, Unadjusted, Domestic Currency',
#  'Gross Domestic Product, Deflator, Index',
#  'Gross Domestic Product, Deflator, Seasonally Adjusted, Index',
#  'Gross Domestic Product, Nominal, Domestic Currency',
#  'Gross Domestic Product, Nominal, Seasonally Adjusted, Domestic Currency',
#  'Gross Domestic Product, Nominal, Unadjusted, Domestic Currency',
#  'Gross Domestic Product, Real, Domestic Currency',
#  'Gross Domestic Product, Real, Seasonally Adjusted, Domestic Currency',
#  'Gross Domestic Product, Real, Unadjusted, Domestic Currency',
#  'Gross Fixed Capital Formation, Nominal, Domestic Currency',
#  'Gross Fixed Capital Formation, Nominal, Seasonally Adjusted, Domestic Currency',
#  'Gross Fixed Capital Formation, Nominal, Unadjusted, Domestic Currency',
#  'Gross Fixed Capital Formation, Real, Domestic Currency',
#  'Gross Fixed Capital Formation, Real, Seasonally Adjusted, Domestic Currency',
#  'Gross Fixed Capital Formation, Real, Unadjusted, Domestic Currency',
#  'Imports of Goods and Services, Nominal, Domestic Currency',
#  'Imports of Goods and Services, Nominal, Seasonally Adjusted, Domestic Currency',
#  'Imports of Goods and Services, Nominal, Unadjusted, Domestic Currency',
#  'Imports of Goods and Services, Real, Domestic Currency',
#  'Imports of Goods and Services, Real, Seasonally Adjusted, Domestic Currency',
#  'Imports of Goods and Services, Real, Unadjusted, Domestic Currency',
#  'Indicators of Economic Activity, Other Indicators. Tourism, Number of Tourist Nights, Number',
#  'Indicators of Economic Activity, Other Indicators. Tourism, Number of Tourist Nights, Percentage change, Corresponding period previous year, Percent',
#  'Indicators of Economic Activity, Retail Sales, Index',
#  'Indicators of Economic Activity, Retail Sales, Percentage change, Previous period, Percent',
#  'Industrial Production, Percentage change, corresponding period previous year, Seasonally adjusted, Percent',
#  'Industrial Production, Percentage change, previous period, Seasonally adjusted, Percent',
#  'Industrial Production, Seasonally adjusted, Index',
#  'International Liquidity, Gold Holdings, National Valuation, SDRs',
#  'International Liquidity, Gold Holdings, National Valuation, US Dollars',
#  'International Liquidity, Total Reserves Minus Gold, Other Reserve Assets, SDRs',
#  'International Liquidity, Total Reserves Minus Gold, Other Reserve Assets, US Dollars',
#  'International Liquidity, Total Reserves excluding Gold, Foreign Exchange, SDRs',
#  'International Liquidity, Total Reserves excluding Gold, Foreign Exchange, US Dollars',
#  'International Liquidity, Total Reserves excluding Gold, SDRs',
#  'International Liquidity, Total Reserves excluding Gold, US Dollars',
#  'International Reserves, Official Reserve Assets, Gold (Including Gold Deposits and, If Appropriate, Gold Swapped) , SDRs',
#  'International Reserves, Official Reserve Assets, Gold (Including Gold Deposits and, If Appropriate, Gold Swapped) , US Dollars',
#  'International Reserves, Official Reserve Assets, Gold (Including Gold Deposits and, If Appropriate, Gold Swapped), Volume in Millions of Fine Troy Ounces , Fine Troy Ounces',
#  'International Reserves, Official Reserve Assets, Gold at Market Price, SDRs',
#  'International Reserves, Official Reserve Assets, Gold at Market Price, US Dollars',
#  'International Reserves, Official Reserve Assets, IMF Reserve Position, SDRs',
#  'International Reserves, Official Reserve Assets, IMF Reserve Position, US Dollars',
#  'International Reserves, Official Reserve Assets, Market Value, SDRs',
#  'International Reserves, Official Reserve Assets, SDRs',
#  'International Reserves, Official Reserve Assets, SDRs, SDRs',
#  'International Reserves, Official Reserve Assets, SDRs, US Dollars',
#  'International Reserves, Official Reserve Assets, US Dollars',
#  'Labor Force, Persons, Number of',
#  'Labor Force, Persons, Percentage change, corresponding period previous year, Percent',
#  'Labor Force, Persons, Percentage change, previous period, Percent',
#  'Labor Markets, Employment, Index',
#  'Labor Markets, Unemployment Rate, Percent',
#  'Labor Markets, Unemployment Rate, Percentage change, Corresponding period previous year, Percent',
#  'Labor Markets, Unemployment Rate, Percentage change, Previous period, Percent',
#  'Labor Markets, Wage Rates, Index',
#  'Labor Markets, Wage Rates, Percentage change, Corresponding period previous year, Percent',
#  'Labor Markets, Wage Rates, Percentage change, Previous period, Percent',
#  'Liabilities (with Fund Record), US Dollars',
#  'Liabilities, Direct Investment, Debt Instruments, US Dollars',
#  'Liabilities, Direct Investment, Equity and Investment Fund Shares, US Dollars',
#  'Liabilities, Direct Investment, US Dollars',
#  'Liabilities, Financial Derivatives (Other Than Reserves) and Employee Stock Options, US Dollars',
#  'Liabilities, Other Investment, Net Incurrence of Liabilities, Debt Instruments (with Fund Record), US Dollars',
#  'Liabilities, Other Investment, Other Equity, US Dollars',
#  'Liabilities, Other Investment, Other Liabilities (with Fund Record), US Dollars',
#  'Liabilities, Portfolio Investment, Debt Securities, US Dollars',
#  'Liabilities, Portfolio Investment, Equity and Investment Fund Shares, US Dollars',
#  'Liabilities, Portfolio Investment, US Dollars',
#  'Monetary, Banking Institutions, Capital Accounts (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Central or General Government Deposits (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Claims on Central Government (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Claims on Private Sector (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Credit from Monetary Authorities (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Demand Deposits (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Foreign Assets (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Foreign Liabilities (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Other Items, Net (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Reserves (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Banking Institutions, Time, Savings, and Foreign Currency Deposits (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Central Bank Survey, Claims on Other Depository Corporations, Euros',
#  'Monetary, Central Bank Survey, Claims on Other Sectors, Claims on Other Financial Corporations, Euros',
#  'Monetary, Central Bank Survey, Claims on Other Sectors, Claims on Private Sector, Euros',
#  'Monetary, Central Bank Survey, Claims on Other Sectors, Claims on State and Local Government, Euros',
#  'Monetary, Central Bank Survey, Claims on Other Sectors, Euros',
#  'Monetary, Central Bank Survey, Monetary Base, Liabilities To Other Depository Corporations, Euros',
#  'Monetary, Central Bank Survey, Monetary Base, Liabilities To Other Sectors, Euros',
#  'Monetary, Central Bank Survey, Net Claims on Central Government, Claims on Central Government, Euros',
#  'Monetary, Central Bank Survey, Net Claims on Central Government, Euros',
#  'Monetary, Central Bank Survey, Net Claims on Central Government, Liabilities To Central Government, Euros',
#  'Monetary, Central Bank Survey, Net Claims on Eurosystem, Euros',
#  'Monetary, Central Bank Survey, Net Foreign Assets, Claims on Non-residents, Euros',
#  'Monetary, Central Bank Survey, Net Foreign Assets, Claims on Non-residents, Other Foreign Assets, International Liquidity, US Dollars',
#  'Monetary, Central Bank Survey, Net Foreign Assets, Euros',
#  'Monetary, Central Bank Survey, Net Foreign Assets, Liabilities To Non-residents, Euros',
#  'Monetary, Central Bank Survey, Net Foreign Assets, Liabilities To Non-residents, Other Foreign Liabilities, International Liquidity, US Dollars',
#  'Monetary, Central Bank Survey, Other Liabilities To Other Depository Corporations, Euros',
#  'Monetary, Deposit Money Banks, Bonds (Debt Securities) (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Depository Corporations Survey, Broad Money Liabilities, Other Deposits (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Broad Money Liabilities, Securities other than Shares (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Broad Money Liabilities, Transferable Deposits (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Deposits Excluded from Broad Money (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Domestic Claims (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Domestic Claims, Claims on Other Sectors (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Domestic Claims, Claims on Other Sectors, Claims on Other Financial Corporations (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Domestic Claims, Claims on Other Sectors, Claims on Private Sector (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Domestic Claims, Claims on Other Sectors, Claims on State and Local Government (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Domestic Claims, Net Claims on Central Government (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Domestic Claims, Net Claims on Central Government, Claims on Central Government (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Domestic Claims, Net Claims on Central Government, Liabilities to Central Government (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Claims on Non-residents, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Claims on Other Sectors, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Currency Issued, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Demand Deposits, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Domestic Claims, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Liabilities to Central Government, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Liabilities to Non-residents, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Net Foreign Assets, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Other Deposits, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Other Items (net), Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Securities other than Shares, Euros',
#  'Monetary, Depository Corporations Survey, Euro area-Wide-Residency, Shares and Other Equity, Euros',
#  'Monetary, Depository Corporations Survey, Net Foreign Assets (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Net Foreign Assets, Claims on Non-residents (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Net Foreign Assets, Liabilities to Non-residents (refers to the Depository Corporations), Euros',
#  'Monetary, Depository Corporations Survey, Securities other than Shares Excluded from Broad Money (refers to the Depository Corporations), Euros',
#  'Monetary, Monetary Authorities, Capital Accounts (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Central or General Government Deposits (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Claims on Central Government (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Claims on Deposit Money Banks (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Claims on Private Sector (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Foreign Assets (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Foreign Liabilities (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Other Items, Net (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Reserve Money, Bankers Deposits (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Reserve Money, Private Sector Deposits (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Authorities, Reserve Money, of which: Currency Outside Banking Institutions (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Bonds (Debt Securities) (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Capital Accounts (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Claims on Central Government, Net (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Claims on Private Sector (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Domestic Credit (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Foreign Assets, Net (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Money, Currency Issued (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Money, Demand Deposits (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Other Items, Net (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Monetary Survey, Quasi-Money, Other Deposits (Non-Standardized Presentation), Domestic Currency',
#  'Monetary, Other Depository Corporations Survey, Claims on Other Sectors, Claims on Other Financial Corporations, Euros',
#  'Monetary, Other Depository Corporations Survey, Claims on Other Sectors, Claims on Private Sector, Euros',
#  'Monetary, Other Depository Corporations Survey, Claims on Other Sectors, Claims on State and Local Government, Euros',
#  'Monetary, Other Depository Corporations Survey, Claims on Other Sectors, Euros',
#  'Monetary, Other Depository Corporations Survey, Deposits Excluded from Broad Money, Euros',
#  'Monetary, Other Depository Corporations Survey, Net Claims on Central Government, Claims on Central Government, Euros',
#  'Monetary, Other Depository Corporations Survey, Net Claims on Central Government, Euros',
#  'Monetary, Other Depository Corporations Survey, Net Claims on Central Government, Liabilities to Central Government, Euros',
#  'Monetary, Other Depository Corporations Survey, Net Foreign Assets, Claims on Non-residents, Euros',
#  'Monetary, Other Depository Corporations Survey, Net Foreign Assets, Euros',
#  'Monetary, Other Depository Corporations Survey, Net Foreign Assets, Liabilities to Non-residents, Euros',
#  'Monetary, Other Depository Corporations Survey, Other Deposits Included In Broad Money, Euros',
#  'Monetary, Other Depository Corporations Survey, Securities other than Shares Excluded from Broad Money, Euros',
#  'Monetary, Other Depository Corporations Survey, Securities other than Shares Included In Broad Money, Euros',
#  'Monetary, Other Depository Corporations Survey, Transferable Deposits Included In Broad Money, Euros',
#  'Monetary, Other Depository Corporations, Assets, Euros',
#  'Other Depository Corporations Survey, Claims on Central Government (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Claims on Eurosystem (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Claims on Nonresidents (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Claims on Other Financial Corporations (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Claims on Other Sectors (Euro area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Claims on Private  Sector (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Claims on Public Nonfinancial Corporations (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Claims on State and Local Government (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Currency (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Demand Deposits (Euro area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Deposits Excluded from Broad Money (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Financial Derivatives (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Insurance Technical Reserves ((Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Liabilities to Central Government (Euro area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Liabilities to Eurosystem (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Liabilities to Nonresidents (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Loans (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Net Claims on Central Government (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Net Foreign Assets (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Other Claims on Central Bank (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Other Deposits (Euro area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Other Items Net (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Reserve Deposits and Securities Other than Shares (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Securities Other Than Shares (Euro area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Securities Other than Shares excl. from Broad Money (Euro Area-Wide-Residency), Euros',
#  'Other Depository Corporations Survey, Shares and Other Equity (Euro Area-Wide-Residency), Euros',
#  'Population, Persons, Number of',
#  'Prices, Consumer Price Index, All items, Index',
#  'Prices, Consumer Price Index, All items, Percentage change, Corresponding period previous year, Percent',
#  'Prices, Consumer Price Index, All items, Percentage change, Previous period, Percent',
#  'Prices, Consumer Price Index, Harmonized, Index',
#  'Prices, Export Price Index, All Commodities, Index',
#  'Prices, Import Price Index, All Commodities, Index',
#  'Prices, Producer Price Index, All Commodities, Index',
#  'Private Sector Final Consumption Expenditure, Nominal, Domestic Currency',
#  'Private Sector Final Consumption Expenditure, Nominal, Seasonally Adjusted, Domestic Currency',
#  'Private Sector Final Consumption Expenditure, Nominal, Unadjusted, Domestic Currency',
#  'Private Sector Final Consumption Expenditure, Real, Domestic Currency',
#  'Private Sector Final Consumption Expenditure, Real, Seasonally Adjusted, Domestic Currency',
#  'Private Sector Final Consumption Expenditure, Real, Unadjusted, Domestic Currency',
#  'Supplementary Items, Balance on Goods, Services, and Income, US Dollars',
#  'Supplementary Items, Capital Account (Excludes Reserves and Related Items), US Dollars',
#  'Supplementary Items, Capital Account, Credit (Excludes Reserves and Related Items), US Dollars',
#  'Supplementary Items, Current Account, Net (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Current Acct + Capital Acct + Financial Acct, US Dollars',
#  'Supplementary Items, Direct Investment, Net Incurrence of Liabilities (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Direct Investment, Net Incurrence of Liabilities, Equity and Investment Fund Shares (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Direct Investment: Net Incurrence of Liabilities: Debt Instruments (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Errors and Omissions (with Fund Record), US Dollars',
#  'Supplementary Items, Financial Account, Net (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Net Credit and Loans from the IMF (Excluding Reserve Position), US Dollars',
#  'Supplementary Items, Other Investment: Net Incurrence of Liabilities, Debt Instruments (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Other Investment: Net Incurrence of Liabilities, Debt Instruments, Of which: Other Financial Corporations Of which: Other Financial Corporations (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Other Investment: Other Equity: Net Incurrence of Liabilities (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Portfolio Investment, Net Incurrence of Liabilities (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Portfolio Investment, Net Incurrence of Liabilities, Debt Securities (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Portfolio Investment, Net Incurrence of Liabilities, Equity Securities (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Reserve Assets (with Fund Record), US Dollars',
#  'Supplementary Items, Reserves and Related items, US Dollars',
#  'Supplementary Items, Secondary Income, Credit (Excluding Exceptional Financing), US Dollars',
#  'Supplementary Items, Total Current + Capital Account, US Dollars',
#  'Total International Reserves, SDRs (gold at 35 SDRs per ounce)',
#  'Total International Reserves, US Dollars (gold at 35 SDRs per ounce)',
#  'Total Reserves, US Dollars (Gold at Market Price)',
#  'Tourism, Number of Visitors, Persons, Number of',
#  'Unemployment, Persons, Number of',
#  'Unemployment, Persons, Percentage change, corresponding period previous year, Percent',
#  'Unemployment, Persons, Percentage change, previous period, Percent'}

# %%
# invert indicators map
indicators_map: dict[str, list[str]] = {}

# %%
countries["Financial, Interest Rates, Lending Rate, Percent per annum"]
# Out:
# {'Afghanistan, Islamic Rep. of',
#  'Albania',
#  'Algeria',
#  'Angola',
#  'Anguilla',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia, Rep. of',
#  'Aruba, Kingdom of the Netherlands',
#  'Australia',
#  'Azerbaijan, Rep. of',
#  'Bahamas, The',
#  'Bahrain, Kingdom of',
#  'Bangladesh',
#  'Barbados',
#  'Belarus, Rep. of',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cameroon',
#  'Canada',
#  'Central African Economic and Monetary Community',
#  'Chile',
#  'China, P.R.: Hong Kong',
#  'China, P.R.: Macao',
#  'China, P.R.: Mainland',
#  'Colombia',
#  'Comoros, Union of the',
#  'Congo, Dem. Rep. of the',
#  'Congo, Rep. of',
#  'Costa Rica',
#  'Croatia, Rep. of',
#  'Cyprus',
#  'Czech Rep.',
#  "Côte d'Ivoire",
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Rep.',
#  'Eastern Caribbean Currency Union (ECCU)',
#  'Ecuador',
#  'Egypt, Arab Rep. of',
#  'El Salvador',
#  'Equatorial Guinea, Rep. of',
#  'Eswatini, Kingdom of',
#  'Ethiopia, The Federal Dem. Rep. of',
#  'Euro Area',
#  'Fiji, Rep. of',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia, The',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran, Islamic Rep. of',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kenya',
#  'Korea, Rep. of',
#  'Kosovo, Rep. of',
#  'Kuwait',
#  'Kyrgyz Rep.',
#  "Lao People's Dem. Rep.",
#  'Lebanon',
#  'Lesotho, Kingdom of',
#  'Liberia',
#  'Libya',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar, Rep. of',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Mauritania, Islamic Rep. of',
#  'Mauritius',
#  'Mexico',
#  'Micronesia, Federated States of',
#  'Moldova, Rep. of',
#  'Mongolia',
#  'Montenegro',
#  'Montserrat',
#  'Morocco',
#  'Mozambique, Rep. of',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Netherlands Antilles',
#  'Netherlands, The',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Macedonia, Republic of',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland, Rep. of',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Samoa',
#  'San Marino, Rep. of',
#  'Senegal',
#  'Serbia, Rep. of',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovak Rep.',
#  'Slovenia, Rep. of',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Sudan, Rep. of',
#  'Spain',
#  'Sri Lanka',
#  'St. Kitts and Nevis',
#  'St. Lucia',
#  'St. Vincent and the Grenadines',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Rep.',
#  'São Tomé and Príncipe, Dem. Rep. of',
#  'Tajikistan, Rep. of',
#  'Tanzania, United Rep. of',
#  'Thailand',
#  'Timor-Leste, Dem. Rep. of',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Uganda',
#  'Ukraine',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan, Rep. of',
#  'Vanuatu',
#  'Venezuela, Rep. Bolivariana de',
#  'Vietnam',
#  'West African Economic and Monetary Union (WAEMU)',
#  'West Bank and Gaza',
#  'Yemen, Rep. of',
#  'Zambia',
#  'Zimbabwe'}

# %%
list_indicators = list(countries.keys())
list_countries = list(indicators.keys())

# create df with indicators as rows and countries as columns
df = pd.DataFrame(index=list_indicators, columns=list_countries)
df["Indicator"] = list_indicators

# fill df with 1 if indicator is present in country
for country in list_countries:
    for indicator in list_indicators:
        df.at[indicator, country] = 1 if country in countries[indicator] else 0

# df.to_csv("../data/cleaned/indicators_countries.csv")

# %%
df
# Out:
#                                                    Afghanistan, Islamic Rep. of  \
# Fund Accounts, UFC & Loans, SDRs                                              1
# Fund Accounts, Outstanding Loans, SDRs                                        1
# Fund Accounts, SDR Holdings as % of Allocation,...                            1
# Fund Accounts, SDR Holdings, Allocations, SDRs                                1
# Fund Accounts, Quota, SDRs                                                    1
# ...                                                                         ...
# Monetary, Other Banking Institutions and Nonban...                            0
# Monetary, Monetary Survey, Domestic Claims, Cla...                            0
# Monetary, Banking Survey and Financial Survey, ...                            0
# Monetary, Banking Survey and Financial Survey, ...                            0
# Monetary, Banking Survey and Financial Survey, ...                            0
#
#                                                    Advanced Economies Angola  \
# Fund Accounts, UFC & Loans, SDRs                                    1      1
# Fund Accounts, Outstanding Loans, SDRs                              1      1
# Fund Accounts, SDR Holdings as % of Allocation,...                  1      1
# Fund Accounts, SDR Holdings, Allocations, SDRs                      1      1
# Fund Accounts, Quota, SDRs                                          1      1
# ...                                                               ...    ...
# Monetary, Other Banking Institutions and Nonban...                  0      0
# Monetary, Monetary Survey, Domestic Claims, Cla...                  0      0
# Monetary, Banking Survey and Financial Survey, ...                  0      0
# Monetary, Banking Survey and Financial Survey, ...                  0      0
# Monetary, Banking Survey and Financial Survey, ...                  0      0
#
#                                                    Algeria Albania  \
# Fund Accounts, UFC & Loans, SDRs                         1       1
# Fund Accounts, Outstanding Loans, SDRs                   1       1
# Fund Accounts, SDR Holdings as % of Allocation,...       1       1
# Fund Accounts, SDR Holdings, Allocations, SDRs           1       1
# Fund Accounts, Quota, SDRs                               1       1
# ...                                                    ...     ...
# Monetary, Other Banking Institutions and Nonban...       0       0
# Monetary, Monetary Survey, Domestic Claims, Cla...       0       0
# Monetary, Banking Survey and Financial Survey, ...       0       0
# Monetary, Banking Survey and Financial Survey, ...       0       0
# Monetary, Banking Survey and Financial Survey, ...       0       0
#
#                                                    Andorra, Principality of  \
# Fund Accounts, UFC & Loans, SDRs                                          1
# Fund Accounts, Outstanding Loans, SDRs                                    1
# Fund Accounts, SDR Holdings as % of Allocation,...                        1
# Fund Accounts, SDR Holdings, Allocations, SDRs                            1
# Fund Accounts, Quota, SDRs                                                1
# ...                                                                     ...
# Monetary, Other Banking Institutions and Nonban...                        0
# Monetary, Monetary Survey, Domestic Claims, Cla...                        0
# Monetary, Banking Survey and Financial Survey, ...                        0
# Monetary, Banking Survey and Financial Survey, ...                        0
# Monetary, Banking Survey and Financial Survey, ...                        0
#
#                                                    Armenia, Rep. of Australia  \
# Fund Accounts, UFC & Loans, SDRs                                  1         1
# Fund Accounts, Outstanding Loans, SDRs                            1         1
# Fund Accounts, SDR Holdings as % of Allocation,...                1         1
# Fund Accounts, SDR Holdings, Allocations, SDRs                    1         1
# Fund Accounts, Quota, SDRs                                        1         1
# ...                                                             ...       ...
# Monetary, Other Banking Institutions and Nonban...                0         0
# Monetary, Monetary Survey, Domestic Claims, Cla...                0         0
# Monetary, Banking Survey and Financial Survey, ...                0         0
# Monetary, Banking Survey and Financial Survey, ...                0         0
# Monetary, Banking Survey and Financial Survey, ...                0         0
#
#                                                    Argentina  \
# Fund Accounts, UFC & Loans, SDRs                           1
# Fund Accounts, Outstanding Loans, SDRs                     1
# Fund Accounts, SDR Holdings as % of Allocation,...         1
# Fund Accounts, SDR Holdings, Allocations, SDRs             1
# Fund Accounts, Quota, SDRs                                 1
# ...                                                      ...
# Monetary, Other Banking Institutions and Nonban...         0
# Monetary, Monetary Survey, Domestic Claims, Cla...         0
# Monetary, Banking Survey and Financial Survey, ...         0
# Monetary, Banking Survey and Financial Survey, ...         0
# Monetary, Banking Survey and Financial Survey, ...         0
#
#                                                    Antigua and Barbuda  ...  \
# Fund Accounts, UFC & Loans, SDRs                                     1  ...
# Fund Accounts, Outstanding Loans, SDRs                               1  ...
# Fund Accounts, SDR Holdings as % of Allocation,...                   1  ...
# Fund Accounts, SDR Holdings, Allocations, SDRs                       1  ...
# Fund Accounts, Quota, SDRs                                           1  ...
# ...                                                                ...  ...
# Monetary, Other Banking Institutions and Nonban...                   0  ...
# Monetary, Monetary Survey, Domestic Claims, Cla...                   0  ...
# Monetary, Banking Survey and Financial Survey, ...                   0  ...
# Monetary, Banking Survey and Financial Survey, ...                   0  ...
# Monetary, Banking Survey and Financial Survey, ...                   0  ...
#
#                                                    West African Economic and Monetary Union (WAEMU)  \
# Fund Accounts, UFC & Loans, SDRs                                                                  1
# Fund Accounts, Outstanding Loans, SDRs                                                            1
# Fund Accounts, SDR Holdings as % of Allocation,...                                                1
# Fund Accounts, SDR Holdings, Allocations, SDRs                                                    1
# Fund Accounts, Quota, SDRs                                                                        1
# ...                                                                                             ...
# Monetary, Other Banking Institutions and Nonban...                                                0
# Monetary, Monetary Survey, Domestic Claims, Cla...                                                0
# Monetary, Banking Survey and Financial Survey, ...                                                0
# Monetary, Banking Survey and Financial Survey, ...                                                0
# Monetary, Banking Survey and Financial Survey, ...                                                0
#
#                                                    West Bank and Gaza World  \
# Fund Accounts, UFC & Loans, SDRs                                    0     1
# Fund Accounts, Outstanding Loans, SDRs                              0     1
# Fund Accounts, SDR Holdings as % of Allocation,...                  0     1
# Fund Accounts, SDR Holdings, Allocations, SDRs                      0     1
# Fund Accounts, Quota, SDRs                                          0     1
# ...                                                               ...   ...
# Monetary, Other Banking Institutions and Nonban...                  0     0
# Monetary, Monetary Survey, Domestic Claims, Cla...                  0     0
# Monetary, Banking Survey and Financial Survey, ...                  0     0
# Monetary, Banking Survey and Financial Survey, ...                  0     0
# Monetary, Banking Survey and Financial Survey, ...                  0     0
#
#                                                    Yemen, Rep. of Yugoslavia  \
# Fund Accounts, UFC & Loans, SDRs                                1          1
# Fund Accounts, Outstanding Loans, SDRs                          1          1
# Fund Accounts, SDR Holdings as % of Allocation,...              1          1
# Fund Accounts, SDR Holdings, Allocations, SDRs                  1          1
# Fund Accounts, Quota, SDRs                                      1          1
# ...                                                           ...        ...
# Monetary, Other Banking Institutions and Nonban...              0          0
# Monetary, Monetary Survey, Domestic Claims, Cla...              0          0
# Monetary, Banking Survey and Financial Survey, ...              0          0
# Monetary, Banking Survey and Financial Survey, ...              0          0
# Monetary, Banking Survey and Financial Survey, ...              0          0
#
#                                                    Zambia Yemen Arab Rep.  \
# Fund Accounts, UFC & Loans, SDRs                        1               1
# Fund Accounts, Outstanding Loans, SDRs                  1               1
# Fund Accounts, SDR Holdings as % of Allocation,...      1               1
# Fund Accounts, SDR Holdings, Allocations, SDRs          1               1
# Fund Accounts, Quota, SDRs                              1               1
# ...                                                   ...             ...
# Monetary, Other Banking Institutions and Nonban...      0               0
# Monetary, Monetary Survey, Domestic Claims, Cla...      0               0
# Monetary, Banking Survey and Financial Survey, ...      0               0
# Monetary, Banking Survey and Financial Survey, ...      0               0
# Monetary, Banking Survey and Financial Survey, ...      0               0
#
#                                                    Yemen, People's Dem. Rep. of  \
# Fund Accounts, UFC & Loans, SDRs                                              1
# Fund Accounts, Outstanding Loans, SDRs                                        1
# Fund Accounts, SDR Holdings as % of Allocation,...                            1
# Fund Accounts, SDR Holdings, Allocations, SDRs                                1
# Fund Accounts, Quota, SDRs                                                    1
# ...                                                                         ...
# Monetary, Other Banking Institutions and Nonban...                            0
# Monetary, Monetary Survey, Domestic Claims, Cla...                            0
# Monetary, Banking Survey and Financial Survey, ...                            0
# Monetary, Banking Survey and Financial Survey, ...                            0
# Monetary, Banking Survey and Financial Survey, ...                            0
#
#                                                    Zimbabwe  \
# Fund Accounts, UFC & Loans, SDRs                          1
# Fund Accounts, Outstanding Loans, SDRs                    1
# Fund Accounts, SDR Holdings as % of Allocation,...        1
# Fund Accounts, SDR Holdings, Allocations, SDRs            1
# Fund Accounts, Quota, SDRs                                1
# ...                                                     ...
# Monetary, Other Banking Institutions and Nonban...        0
# Monetary, Monetary Survey, Domestic Claims, Cla...        0
# Monetary, Banking Survey and Financial Survey, ...        0
# Monetary, Banking Survey and Financial Survey, ...        0
# Monetary, Banking Survey and Financial Survey, ...        0
#
#                                                                                             Indicator
# Fund Accounts, UFC & Loans, SDRs                                     Fund Accounts, UFC & Loans, SDRs
# Fund Accounts, Outstanding Loans, SDRs                         Fund Accounts, Outstanding Loans, SDRs
# Fund Accounts, SDR Holdings as % of Allocation,...  Fund Accounts, SDR Holdings as % of Allocation...
# Fund Accounts, SDR Holdings, Allocations, SDRs         Fund Accounts, SDR Holdings, Allocations, SDRs
# Fund Accounts, Quota, SDRs                                                 Fund Accounts, Quota, SDRs
# ...                                                                                               ...
# Monetary, Other Banking Institutions and Nonban...  Monetary, Other Banking Institutions and Nonba...
# Monetary, Monetary Survey, Domestic Claims, Cla...  Monetary, Monetary Survey, Domestic Claims, Cl...
# Monetary, Banking Survey and Financial Survey, ...  Monetary, Banking Survey and Financial Survey,...
# Monetary, Banking Survey and Financial Survey, ...  Monetary, Banking Survey and Financial Survey,...
# Monetary, Banking Survey and Financial Survey, ...  Monetary, Banking Survey and Financial Survey,...
#
# [1618 rows x 230 columns]

# %%
df.to_excel("../data/cleaned/indicators_countries.xlsx")
